# %%
import pickle

import numpy as np
import matplotlib.pyplot as plt

from data.mnist import Mnist

# %%
loader = Mnist()

# %%
loader.train_labels.shape
# Out:
# (60000,)

# %%
plt.imshow(np.reshape(loader.train_features[0], newshape=[28, 28]))

# %%
with open("../../learned-models/VAE-MNIST/VAE-MNIST/VAE-MNIST-results.pickle", "rb") as f:
    _, _, _, fs = pickle.load(f)

print(len(fs))
for f in fs:
    plt.figure()
    plt.imshow(np.reshape(np.clip(f, 0, 1), newshape=[28, 28]))
    plt.show()
# Out:
# 85
